# %%
#KNN trained with non-linear data, with data augmentation SAME for each label and using labels-v4

# %%
import numpy as np
import pandas as pd
import random
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import os
import time

# %%
# nombre de instancia
# número restricciones
# número variables
# si es lineal o no (true / false)
# porcentaje de restricciones unarias, binarias, porcentaje de ternarias, porcentaje cuaternarias o más 
# porcentaje de terminos unarios, binarios, porcentaje de ternarios, porcentaje cuaternarios o más 
# porcentaje de terminos en la función obj
# porcentaje de terminos positivos/negativos en restricciones
# porcentaje de terminos positivos/negativos en funcion obj
# timestep
# solver (label)

main_path="/global/scratch/users/cpezov/AAPBO/"
d_path=main_path+"datasets-v4/"
feat_path=d_path+"features/"

columns = ["# contraints","# variables","linearity","% 1 term constr","% 2 terms constr","% 3 terms constr","% 4+ terms constr","% degree 1 terms","% degree 2 terms","% degree 3 terms","% degree 4+ terms","% terms in obj func","% positive in constr","% positive in obj func","timestep","solver"]
names=[]
num_rest=[]
num_var=[]
linear=[]
r_unary=[]
r_binary=[]
r_ternary=[]
r_cuaternary=[]
t_unary=[]
t_binary=[]
t_ternary=[]
t_cuaternary=[]
t_fo=[]
t_pos_r=[]
t_pos_fo=[]
timestep=[]
solvers=[]

#Recolectar data de txt files
with open(d_path+"txt_files/data_ordered.txt") as f:
    lines = f.readlines()
    for l in lines:
        words=l.split()
        name=words[0][words[0].find("/")+1:]
        print(name)
        with open(feat_path+name) as feat_f:
            l=feat_f.readlines()
            w=l[0].split()
            for n in range(500): #repetir 500 cada instancia, para que cuadre con los timesteps
                names.append(w[0])
                num_rest.append(int(w[1]))
                num_var.append(int(w[2]))
                linear.append(int(w[3]))
                r_unary.append(float(w[4]))
                r_binary.append(float(w[5]))
                r_ternary.append(float(w[6]))
                r_cuaternary.append(float(w[7]))
                t_unary.append(float(w[8]))
                t_binary.append(float(w[9]))
                t_ternary.append(float(w[10]))
                t_cuaternary.append(float(w[11]))
                t_fo.append(float(w[12]))
                t_pos_r.append(float(w[13]))
                t_pos_fo.append(float(w[14]))
                timestep.append(n)
        
with open(main_path+"labels-v4.txt") as f:
    lines = f.readlines()
    for l in lines:
        for word in l.split():
            solvers.append(int(word))
# Out:
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-B-3-2-irabcde.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-B-3-2-irEDCBA.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-B-3-1-irabcde.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-B-3-1-irEDCBA.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-2-irabcde.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-2-irEDCBA.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-1-irabcde.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-1-irEDCBA.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-1-abcdeir.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-combined-EDCBAir.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-B-3-combined-irabcde.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-B-3-combined-irEDCBA.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-B-3-combined-EDCBAir.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-combined-irabcde.opb
# Benchmark1/normalized-single-obj-f4-DataDisplay_2_order9.seq-A-3-combined-irEDCBA.opb
# Benchmark2/normalized-single-obj-f6-ACTotalLoss.seq-A-2-2-irEDCBA.opb
# Benchmark2/normalized-single-obj-f6-ACTotalLoss.seq-B-2-2-irEDCBA.opb
# Benchmark2/normalized-single-obj-f6-ACTotalLoss.seq-B-2-1-irabcde.opb
# Benchmark2/normalized-single-obj-f6-ACTotalLoss.seq-A-2-combined-irabcde.opb
# Benchmark2/normalized-single-obj-f6-ACTotalLoss.seq-B-2-combined-irabcde.opb
# Benchmark2/normalized-single-obj-f6-ACTotalLoss.seq-B-2-combined-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-2-2-irabcde.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-A-2-2-irabcde.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-B-2-2-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-A-2-2-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-2-1-irabcde.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-2-1-irEDCBA.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-A-2-1-irEDCBA.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-A-2-1-irabcde.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-A-2-combined-irEDCBA.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-A-2-combined-irabcde.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-2-combined-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-2-combined-irabcde.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-A-3-1-irEDCBA.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-B-3-2-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-A-3-1-irabcde.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-A-3-1-EDCBAir.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-A-3-2-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-A-3-2-irabcde.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-B-3-2-irabcde.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-3-1-irabcde.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-3-1-irEDCBA.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-B-3-1-abcdeir.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-B-3-combined-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-A-3-combined-irabcde.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-3-combined-irabcde.opb
# Benchmark3/normalized-single-obj-f11-DCTotalLoss.seq-A-3-combined-irEDCBA.opb
# Benchmark3/normalized-single-obj-f10-DCTotalLoss.seq-B-3-combined-abcdeir.opb
# Benchmark4/normalized-single-obj-f17-DCdoubleLoss.seq-A-2-2-irEDCBA.opb
# Benchmark4/normalized-single-obj-f17-DCdoubleLoss.seq-B-2-2-irEDCBA.opb
# Benchmark4/normalized-single-obj-f17-DCdoubleLoss.seq-B-2-2-irabcde.opb
# Benchmark4/normalized-single-obj-f17-DCdoubleLoss.seq-A-2-2-irabcde.opb
# Benchmark4/normalized-single-obj-f16-DCdoubleLoss.seq-A-2-1-irabcde.opb
# Benchmark4/normalized-single-obj-f16-DCdoubleLoss.seq-B-2-1-irabcde.opb
# Benchmark4/normalized-single-obj-f16-DCdoubleLoss.seq-B-2-1-irEDCBA.opb
# Benchmark4/normalized-single-obj-f16-DCdoubleLoss.seq-A-2-1-abcdeir.opb
# Benchmark4/normalized-single-obj-f16-DCdoubleLoss.seq-A-2-1-irEDCBA.opb
# Benchmark4/normalized-single-obj-f16-DCdoubleLoss.seq-A-2-combined-irabcde.opb
# Benchmark4/normalized-single-obj-f17-DCdoubleLoss.seq-B-2-combined-irabcde.opb
# Benchmark4/normalized-single-obj-f17-DCdoubleLoss.seq-B-2-combined-irEDCBA.opb
# Benchmark4/normalized-single-obj-f16-DCdoubleLoss.seq-A-2-combined-irEDCBA.opb
# Benchmark5/normalized-single-obj-f34-AC_ESS.seq-A-2-2-irEDCBA.opb
# Benchmark5/normalized-single-obj-f33-AC_ESS.seq-B-2-2-irabcde.opb
# Benchmark5/normalized-single-obj-f33-AC_ESS.seq-B-2-2-irEDCBA.opb
# Benchmark5/normalized-single-obj-f33-AC_ESS.seq-A-2-2-irabcde.opb
# Benchmark5/normalized-single-obj-f34-AC_ESS.seq-B-2-1-irEDCBA.opb
# Benchmark5/normalized-single-obj-f34-AC_ESS.seq-A-2-1-irEDCBA.opb
# Benchmark5/normalized-single-obj-f33-AC_ESS.seq-B-2-1-irabcde.opb
# Benchmark5/normalized-single-obj-f33-AC_ESS.seq-A-2-1-irabcde.opb
# Benchmark5/normalized-single-obj-f34-AC_ESS.seq-A-2-combined-irEDCBA.opb
# Benchmark5/normalized-single-obj-f33-AC_ESS.seq-B-2-combined-irabcde.opb
# Benchmark5/normalized-single-obj-f33-AC_ESS.seq-B-2-combined-irEDCBA.opb
# Benchmark5/normalized-single-obj-f34-AC_ESS.seq-A-2-combined-irabcde.opb
# Benchmark6/normalized-single-obj-f38-AC_TotalLoss.seq-A-2-2-irEDCBA.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-B-2-2-irabcde.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-B-2-2-irEDCBA.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-A-2-2-irabcde.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-B-2-1-irabcde.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-B-2-1-irEDCBA.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-A-2-1-irabcde.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-A-2-1-irEDCBA.opb
# Benchmark6/normalized-single-obj-f38-AC_TotalLoss.seq-A-2-combined-irabcde.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-B-2-combined-irabcde.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-B-2-combined-irEDCBA.opb
# Benchmark6/normalized-single-obj-f37-AC_TotalLoss.seq-A-2-combined-irEDCBA.opb
# Benchmark7/normalized-single-obj-f42-DC_DoubleLoss.seq-B-2-2-irabcde.opb
# Benchmark7/normalized-single-obj-f42-DC_DoubleLoss.seq-B-2-2-irEDCBA.opb
# Benchmark7/normalized-single-obj-f42-DC_DoubleLoss.seq-B-2-1-irabcde.opb
# Benchmark7/normalized-single-obj-f42-DC_DoubleLoss.seq-A-2-1-irEDCBA.opb
# Benchmark7/normalized-single-obj-f41-DC_DoubleLoss.seq-B-2-1-irEDCBA.opb
# Benchmark7/normalized-single-obj-f42-DC_DoubleLoss.seq-B-2-combined-irEDCBA.opb
# Benchmark7/normalized-single-obj-f42-DC_DoubleLoss.seq-A-2-combined-irEDCBA.opb
# Benchmark7/normalized-single-obj-f41-DC_DoubleLoss.seq-B-2-combined-irabcde.opb
# Benchmark7/normalized-single-obj-f41-DC_DoubleLoss.seq-A-2-combined-irabcde.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-A-2-2-irEDCBA.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-B-2-2-irEDCBA.opb
# Benchmark8/normalized-single-obj-f43-DC_ESS.seq-A-2-2-irabcde.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-B-2-2-irabcde.opb
# Benchmark8/normalized-single-obj-f43-DC_ESS.seq-A-2-1-abcdeir.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-B-2-1-irabcde.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-A-2-1-irabcde.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-A-2-1-EDCBAir.opb
# Benchmark8/normalized-single-obj-f43-DC_ESS.seq-B-2-1-irEDCBA.opb
# Benchmark8/normalized-single-obj-f43-DC_ESS.seq-A-2-1-irEDCBA.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-B-2-combined-irabcde.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-B-2-combined-irEDCBA.opb
# Benchmark8/normalized-single-obj-f43-DC_ESS.seq-A-2-combined-irEDCBA.opb
# Benchmark8/normalized-single-obj-f44-DC_ESS.seq-A-2-combined-irabcde.opb
# Benchmark9/normalized-single-obj-f41-DC_DoubleLoss.seq-A-2-2-irabcde.opb
# Benchmark9/normalized-single-obj-f41-DC_DoubleLoss.seq-A-2-2-irEDCBA.opb
# Benchmark9/normalized-single-obj-f41-DC_DoubleLoss.seq-A-2-1-irabcde.opb
# Benchmark10/normalized-single-obj-f47-DC_Side1.seq-A-2-2-irEDCBA.opb
# Benchmark10/normalized-single-obj-f47-DC_Side1.seq-B-2-2-irEDCBA.opb
# Benchmark10/normalized-single-obj-f47-DC_Side1.seq-B-2-2-irabcde.opb
# Benchmark10/normalized-single-obj-f46-DC_Side1.seq-A-2-2-irabcde.opb
# Benchmark10/normalized-single-obj-f47-DC_Side1.seq-B-2-1-EDCBAir.opb
# Benchmark10/normalized-single-obj-f46-DC_Side1.seq-B-2-1-irEDCBA.opb
# Benchmark10/normalized-single-obj-f46-DC_Side1.seq-A-2-1-irabcde.opb
# Benchmark10/normalized-single-obj-f46-DC_Side1.seq-A-2-1-irEDCBA.opb
# Benchmark10/normalized-single-obj-f46-DC_Side1.seq-B-2-1-irabcde.opb
# Benchmark10/normalized-single-obj-f47-DC_Side1.seq-B-2-combined-irabcde.opb
# Benchmark10/normalized-single-obj-f47-DC_Side1.seq-B-2-combined-irEDCBA.opb
# Benchmark10/normalized-single-obj-f46-DC_Side1.seq-A-2-combined-irEDCBA.opb
# Benchmark10/normalized-single-obj-f46-DC_Side1.seq-A-2-combined-irabcde.opb
# Benchmark11/normalized-single-obj-f49-DC_TotalLoss.seq-A-2-2-irEDCBA.opb
# Benchmark11/normalized-single-obj-f48-DC_TotalLoss.seq-B-2-2-irabcde.opb
# Benchmark11/normalized-single-obj-f48-DC_TotalLoss.seq-B-2-2-irEDCBA.opb
# Benchmark11/normalized-single-obj-f48-DC_TotalLoss.seq-A-2-2-irabcde.opb
# Benchmark11/normalized-single-obj-f48-DC_TotalLoss.seq-B-2-1-irabcde.opb
# Benchmark11/normalized-single-obj-f49-DC_TotalLoss.seq-B-2-1-irEDCBA.opb
# Benchmark11/normalized-single-obj-f49-DC_TotalLoss.seq-A-2-1-irabcde.opb
# Benchmark11/normalized-single-obj-f49-DC_TotalLoss.seq-A-2-1-irEDCBA.opb
# Benchmark11/normalized-single-obj-f49-DC_TotalLoss.seq-A-2-combined-irEDCBA.opb
# Benchmark11/normalized-single-obj-f48-DC_TotalLoss.seq-B-2-combined-irabcde.opb
# Benchmark11/normalized-single-obj-f48-DC_TotalLoss.seq-B-2-combined-irEDCBA.opb
# Benchmark11/normalized-single-obj-f48-DC_TotalLoss.seq-A-2-combined-irabcde.opb
# Benchmark12/normalized-single-obj-f51-DC_side2.seq-B-2-2-irEDCBA.opb
# Benchmark12/normalized-single-obj-f51-DC_side2.seq-A-2-2-irabcde.opb
# Benchmark12/normalized-single-obj-f51-DC_side2.seq-A-2-2-irEDCBA.opb
# Benchmark12/normalized-single-obj-f51-DC_side2.seq-B-2-2-irabcde.opb
# Benchmark12/normalized-single-obj-f51-DC_side2.seq-B-2-1-irabcde.opb
# Benchmark12/normalized-single-obj-f51-DC_side2.seq-B-2-1-irEDCBA.opb
# Benchmark12/normalized-single-obj-f50-DC_side2.seq-A-2-1-irEDCBA.opb
# Benchmark12/normalized-single-obj-f50-DC_side2.seq-A-2-1-irabcde.opb
# Benchmark12/normalized-single-obj-f50-DC_side2.seq-A-2-combined-irabcde.opb
# Benchmark12/normalized-single-obj-f50-DC_side2.seq-B-2-combined-irabcde.opb
# Benchmark12/normalized-single-obj-f50-DC_side2.seq-B-2-combined-irEDCBA.opb
# Benchmark12/normalized-single-obj-f50-DC_side2.seq-A-2-combined-irEDCBA.opb
# Benchmark13/normalized-single-obj-f52-ACTotalLoss.seq-B-2-2-irabcde.opb
# Benchmark13/normalized-single-obj-f52-ACTotalLoss.seq-A-2-2-irabcde.opb
# Benchmark13/normalized-single-obj-f52-ACTotalLoss.seq-B-2-1-irEDCBA.opb
# Benchmark13/normalized-single-obj-f52-ACTotalLoss.seq-A-2-1-irabcde.opb
# Benchmark13/normalized-single-obj-f52-ACTotalLoss.seq-A-2-1-irEDCBA.opb
# Benchmark13/normalized-single-obj-f52-ACTotalLoss.seq-A-2-combined-irEDCBA.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-2-irabcde.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-2-irEDCBA.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-2-irabcde.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-2-irEDCBA.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-1-irEDCBA.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-1-irEDCBA.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-1-EDCBAir.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-1-irabcde.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-1-EDCBAir.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-1-abcdeir.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-1-abcdeir.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-1-irabcde.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-combined-irabcde.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-combined-irabcde.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-combined-EDCBAir.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-A-2-combined-irEDCBA.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-combined-irEDCBA.opb
# Benchmark14/normalized-single-obj-f53-AC_FC1.seq-B-2-combined-EDCBAir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-2-EDCBAir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-2-irEDCBA.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-2-irabcde.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-2-irEDCBA.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-2-EDCBAir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-2-irabcde.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-1-irabcde.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-1-irEDCBA.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-1-abcdeir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-1-EDCBAir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-1-EDCBAir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-1-irabcde.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-1-irEDCBA.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-1-abcdeir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-combined-irabcde.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-combined-irEDCBA.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-B-2-combined-EDCBAir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-combined-irabcde.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-combined-EDCBAir.opb
# Benchmark15/normalized-single-obj-f56-FCS_FC1_order3_PB.seq-A-2-combined-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-2-2-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-2-2-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-2-2-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-2-1-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-2-1-abcdeir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-2-1-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-2-1-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-2-1-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-2-combined-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-2-combined-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-2-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-2-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-2-abcdeir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-2-EDCBAir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-1-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-1-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-1-abcdeir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-1-EDCBAir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-1-EDCBAir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-2-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-2-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-2-abcdeir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-2-EDCBAir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-1-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-1-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-1-abcdeir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-combined-irabcde.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-combined-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-combined-abcdeir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-B-3-combined-EDCBAir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-combined-EDCBAir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-combined-abcdeir.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-combined-irEDCBA.opb
# Benchmark16/normalized-single-obj-f58-fob_fxl_loss.seq-A-3-combined-irabcde.opb
# Benchmark17/normalized-autocorr_bern45-23.lin.opb
# Benchmark17/normalized-autocorr_bern50-25.lin.opb
# Benchmark17/normalized-autocorr_bern40-40.lin.opb
# Benchmark17/normalized-autocorr_bern45-34.lin.opb
# Benchmark17/normalized-autocorr_bern55-28.lin.opb
# Benchmark17/normalized-autocorr_bern45-45.lin.opb
# Benchmark17/normalized-autocorr_bern60-30.lin.opb
# Benchmark17/normalized-autocorr_bern50-38.lin.opb
# Benchmark17/normalized-autocorr_bern50-50.lin.opb
# Benchmark17/normalized-autocorr_bern55-41.lin.opb
# Benchmark17/normalized-autocorr_bern55-55.lin.opb
# Benchmark17/normalized-autocorr_bern60-45.lin.opb
# Benchmark17/normalized-autocorr_bern60-60.lin.opb
# Benchmark18/normalized-cardqp_inlp.lin.opb
# Benchmark19/normalized-crossdock_15x8.lin.opb
# Benchmark20/normalized-faclay60.lin.opb
# Benchmark20/normalized-faclay70.lin.opb
# Benchmark20/normalized-faclay75.lin.opb
# Benchmark20/normalized-faclay80.lin.opb
# Benchmark21/normalized-graphpart_2g-0044-1601.lin.opb
# Benchmark21/normalized-graphpart_2g-0055-0062.lin.opb
# Benchmark21/normalized-graphpart_2g-0066-0066.lin.opb
# Benchmark21/normalized-graphpart_2g-0077-0077.lin.opb
# Benchmark21/normalized-graphpart_2g-0088-0088.lin.opb
# Benchmark21/normalized-graphpart_2g-0099-9211.lin.opb
# Benchmark21/normalized-graphpart_2g-1010-0824.lin.opb
# Benchmark22/normalized-graphpart_3g-0234-0234.lin.opb
# Benchmark22/normalized-graphpart_3g-0333-0333.lin.opb
# Benchmark22/normalized-graphpart_3g-0244-0244.lin.opb
# Benchmark22/normalized-graphpart_3g-0334-0334.lin.opb
# Benchmark22/normalized-graphpart_3g-0344-0344.lin.opb
# Benchmark22/normalized-graphpart_3g-0444-0444.lin.opb
# Benchmark23/normalized-pb351575.lin.opb
# Benchmark23/normalized-pb351555.lin.opb
# Benchmark23/normalized-pb351535.lin.opb
# Benchmark23/normalized-pb351595.lin.opb
# Benchmark23/normalized-pb302055.lin.opb
# Benchmark23/normalized-pb302035.lin.opb
# Benchmark23/normalized-pb302095.lin.opb
# Benchmark23/normalized-pb302075.lin.opb
# Benchmark24/normalized-qap.lin.opb
# Benchmark25/normalized-hw128-vm90p-opt.opb.negationfix.opb
# Benchmark25/normalized-hw128-vm95p-opt.opb.negationfix.opb
# Benchmark25/normalized-hw128-vm98p-opt.opb.negationfix.opb
# Benchmark25/normalized-hw128-vm99p-opt.opb.negationfix.opb
# Benchmark25/normalized-hw128-vm100p-opt.opb.negationfix.opb
# Benchmark26/normalized-autocorr_bern40-40.opb
# Benchmark26/normalized-autocorr_bern45-23.opb
# Benchmark26/normalized-autocorr_bern45-34.opb
# Benchmark26/normalized-autocorr_bern45-45.opb
# Benchmark26/normalized-autocorr_bern50-25.opb
# Benchmark26/normalized-autocorr_bern50-38.opb
# Benchmark26/normalized-autocorr_bern50-50.opb
# Benchmark26/normalized-autocorr_bern55-28.opb
# Benchmark26/normalized-autocorr_bern55-41.opb
# Benchmark26/normalized-autocorr_bern55-55.opb
# Benchmark26/normalized-autocorr_bern60-30.opb
# Benchmark26/normalized-autocorr_bern60-60.opb
# Benchmark26/normalized-autocorr_bern60-45.opb
# Benchmark27/normalized-cardqp_inlp.opb
# Benchmark28/normalized-crossdock_15x8.opb
# Benchmark29/normalized-faclay60.opb
# Benchmark29/normalized-faclay70.opb
# Benchmark29/normalized-faclay75.opb
# Benchmark29/normalized-faclay80.opb
# Benchmark30/normalized-graphpart_2g-0044-1601.opb
# Benchmark30/normalized-graphpart_2g-0055-0062.opb
# Benchmark30/normalized-graphpart_2g-0066-0066.opb
# Benchmark30/normalized-graphpart_2g-0077-0077.opb
# Benchmark30/normalized-graphpart_2g-0088-0088.opb
# Benchmark30/normalized-graphpart_2g-0099-9211.opb
# Benchmark30/normalized-graphpart_2g-1010-0824.opb
# Benchmark31/normalized-graphpart_3g-0234-0234.opb
# Benchmark31/normalized-graphpart_3g-0333-0333.opb
# Benchmark31/normalized-graphpart_3g-0244-0244.opb
# Benchmark31/normalized-graphpart_3g-0334-0334.opb
# Benchmark31/normalized-graphpart_3g-0344-0344.opb
# Benchmark31/normalized-graphpart_3g-0444-0444.opb
# Benchmark32/normalized-pb351595.opb
# Benchmark32/normalized-pb351555.opb
# Benchmark32/normalized-pb351575.opb
# Benchmark32/normalized-pb351535.opb
# Benchmark32/normalized-pb302075.opb
# Benchmark32/normalized-pb302035.opb
# Benchmark32/normalized-pb302095.opb
# Benchmark32/normalized-pb302055.opb
# Benchmark33/normalized-qap.opb
# Benchmark35/normalized-lo_8x8_001.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_009.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_007.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_008.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_000.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_006.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_002.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_003.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_004.opb.metafix.opb
# Benchmark35/normalized-lo_8x8_005.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_009.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_008.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_007.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_006.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_005.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_004.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_003.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_002.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_001.opb.metafix.opb
# Benchmark36/normalized-lo_10x10_000.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_009.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_008.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_007.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_006.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_005.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_004.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_003.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_002.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_001.opb.metafix.opb
# Benchmark37/normalized-lo_12x12_000.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_009.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_008.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_007.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_006.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_005.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_004.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_003.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_002.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_001.opb.metafix.opb
# Benchmark38/normalized-lo_14x14_000.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_009.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_008.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_007.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_006.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_005.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_004.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_003.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_002.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_001.opb.metafix.opb
# Benchmark39/normalized-lo_16x16_000.opb.metafix.opb
# Benchmark40/normalized-sep5.5.opb
# Benchmark40/normalized-sep4.5.opb
# Benchmark40/normalized-sep6.5.opb
# Benchmark40/normalized-jun6.5.opb
# Benchmark40/normalized-jun5.5.opb
# Benchmark40/normalized-aug4.5.opb
# Benchmark40/normalized-oct6.5.opb
# Benchmark40/normalized-oct5.5.opb
# Benchmark40/normalized-oct4.5.opb
# Benchmark40/normalized-may6.5.opb
# Benchmark40/normalized-may4.5.opb
# Benchmark40/normalized-jul6.5.opb
# Benchmark40/normalized-jul5.5.opb
# Benchmark40/normalized-jul4.5.opb
# Benchmark40/normalized-aug6.5.opb
# Benchmark40/normalized-aug5.5.opb
# Benchmark40/normalized-may5.5.opb
# Benchmark41/normalized-autocorr_bern20-03.lin.opb
# Benchmark41/normalized-autocorr_bern25-03.lin.opb
# Benchmark41/normalized-autocorr_bern20-05.lin.opb
# Benchmark41/normalized-autocorr_bern30-04.lin.opb
# Benchmark41/normalized-autocorr_bern35-04.lin.opb
# Benchmark41/normalized-autocorr_bern25-06.lin.opb
# Benchmark41/normalized-autocorr_bern40-05.lin.opb
# Benchmark41/normalized-autocorr_bern45-05.lin.opb
# Benchmark41/normalized-autocorr_bern20-10.lin.opb
# Benchmark41/normalized-autocorr_bern50-06.lin.opb
# Benchmark41/normalized-autocorr_bern30-08.lin.opb
# Benchmark41/normalized-autocorr_bern55-06.lin.opb
# Benchmark41/normalized-autocorr_bern35-09.lin.opb
# Benchmark41/normalized-autocorr_bern20-15.lin.opb
# Benchmark41/normalized-autocorr_bern25-13.lin.opb
# Benchmark41/normalized-autocorr_bern60-08.lin.opb
# Benchmark41/normalized-autocorr_bern40-10.lin.opb
# Benchmark41/normalized-autocorr_bern45-11.lin.opb
# Benchmark41/normalized-autocorr_bern30-15.lin.opb
# Benchmark41/normalized-autocorr_bern25-19.lin.opb
# Benchmark41/normalized-autocorr_bern25-25.lin.opb
# Benchmark41/normalized-autocorr_bern50-13.lin.opb
# Benchmark41/normalized-autocorr_bern35-18.lin.opb
# Benchmark41/normalized-autocorr_bern30-23.lin.opb
# Benchmark41/normalized-autocorr_bern55-14.lin.opb
# Benchmark41/normalized-autocorr_bern30-30.lin.opb
# Benchmark41/normalized-autocorr_bern40-20.lin.opb
# Benchmark41/normalized-autocorr_bern60-15.lin.opb
# Benchmark41/normalized-autocorr_bern35-26.lin.opb
# Benchmark41/normalized-autocorr_bern40-30.lin.opb
# Benchmark42/normalized-crossdock_15x7.lin.opb
# Benchmark43/normalized-edgecross10-010.lin.opb
# Benchmark43/normalized-edgecross10-020.lin.opb
# Benchmark43/normalized-edgecross10-030.lin.opb
# Benchmark43/normalized-edgecross14-019.lin.opb
# Benchmark43/normalized-edgecross10-040.lin.opb
# Benchmark43/normalized-edgecross10-090.lin.opb
# Benchmark43/normalized-edgecross10-050.lin.opb
# Benchmark43/normalized-edgecross10-070.lin.opb
# Benchmark43/normalized-edgecross14-058.lin.opb
# Benchmark43/normalized-edgecross20-040.lin.opb
# Benchmark43/normalized-edgecross14-176.lin.opb
# Benchmark43/normalized-edgecross22-048.lin.opb
# Benchmark43/normalized-edgecross14-098.lin.opb
# Benchmark43/normalized-edgecross14-117.lin.opb
# Benchmark43/normalized-edgecross24-057.lin.opb
# Benchmark43/normalized-edgecross20-080.lin.opb
# Benchmark43/normalized-edgecross14-137.lin.opb
# Benchmark43/normalized-edgecross22-096.lin.opb
# Benchmark43/normalized-edgecross24-115.lin.opb
# Benchmark44/normalized-faclay20h.lin.opb
# Benchmark44/normalized-faclay25.lin.opb
# Benchmark44/normalized-faclay30h.lin.opb
# Benchmark44/normalized-faclay30.lin.opb
# Benchmark44/normalized-faclay33.lin.opb
# Benchmark44/normalized-faclay35.lin.opb
# Benchmark45/normalized-graphpart_2pm-0044-0044.lin.opb
# Benchmark45/normalized-graphpart_2pm-0055-0055.lin.opb
# Benchmark45/normalized-graphpart_2pm-0066-0066.lin.opb
# Benchmark45/normalized-graphpart_2pm-0077-0777.lin.opb
# Benchmark45/normalized-graphpart_2pm-0088-0888.lin.opb
# Benchmark45/normalized-graphpart_2pm-0099-0999.lin.opb
# Benchmark46/normalized-graphpart_3pm-0234-0234.lin.opb
# Benchmark46/normalized-graphpart_3pm-0333-0333.lin.opb
# Benchmark46/normalized-graphpart_3pm-0244-0244.lin.opb
# Benchmark46/normalized-graphpart_3pm-0334-0334.lin.opb
# Benchmark46/normalized-graphpart_3pm-0344-0344.lin.opb
# Benchmark46/normalized-graphpart_3pm-0444-0444.lin.opb
# Benchmark47/normalized-graphpart_clique-20.lin.opb
# Benchmark47/normalized-graphpart_clique-30.lin.opb
# Benchmark47/normalized-graphpart_clique-40.lin.opb
# Benchmark47/normalized-graphpart_clique-50.lin.opb
# Benchmark47/normalized-graphpart_clique-60.lin.opb
# Benchmark47/normalized-graphpart_clique-70.lin.opb
# Benchmark48/normalized-hmittelman.lin.opb
# Benchmark49/normalized-sporttournament06.lin.opb
# Benchmark49/normalized-sporttournament08.lin.opb
# Benchmark49/normalized-sporttournament10.lin.opb
# Benchmark49/normalized-sporttournament12.lin.opb
# Benchmark49/normalized-sporttournament16.lin.opb
# Benchmark49/normalized-sporttournament18.lin.opb
# Benchmark49/normalized-sporttournament20.lin.opb
# Benchmark49/normalized-sporttournament22.lin.opb
# Benchmark49/normalized-sporttournament24.lin.opb
# Benchmark49/normalized-sporttournament26.lin.opb
# Benchmark49/normalized-sporttournament28.lin.opb
# Benchmark49/normalized-sporttournament30.lin.opb
# Benchmark49/normalized-sporttournament32.lin.opb
# Benchmark49/normalized-sporttournament34.lin.opb
# Benchmark49/normalized-sporttournament36.lin.opb
# Benchmark49/normalized-sporttournament38.lin.opb
# Benchmark49/normalized-sporttournament40.lin.opb
# Benchmark49/normalized-sporttournament42.lin.opb
# Benchmark49/normalized-sporttournament44.lin.opb
# Benchmark49/normalized-sporttournament46.lin.opb
# Benchmark49/normalized-sporttournament48.lin.opb
# Benchmark49/normalized-sporttournament50.lin.opb
# Benchmark50/normalized-hw32-vm25p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm50p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm75p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm85p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm90p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm95p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm98p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm99p-opt.opb.negationfix.opb
# Benchmark50/normalized-hw32-vm100p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm25p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm50p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm75p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm85p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm90p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm95p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm98p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm99p-opt.opb.negationfix.opb
# Benchmark51/normalized-hw64-vm100p-opt.opb.negationfix.opb
# Benchmark52/normalized-hw128-vm25p-opt.opb.negationfix.opb
# Benchmark52/normalized-hw128-vm50p-opt.opb.negationfix.opb
# Benchmark52/normalized-hw128-vm75p-opt.opb.negationfix.opb
# Benchmark52/normalized-hw128-vm85p-opt.opb.negationfix.opb
# Benchmark53/normalized-autocorr_bern20-03.opb
# Benchmark53/normalized-autocorr_bern20-05.opb
# Benchmark53/normalized-autocorr_bern20-10.opb
# Benchmark53/normalized-autocorr_bern20-15.opb
# Benchmark53/normalized-autocorr_bern25-03.opb
# Benchmark53/normalized-autocorr_bern25-25.opb
# Benchmark53/normalized-autocorr_bern25-19.opb
# Benchmark53/normalized-autocorr_bern25-06.opb
# Benchmark53/normalized-autocorr_bern25-13.opb
# Benchmark53/normalized-autocorr_bern30-08.opb
# Benchmark53/normalized-autocorr_bern30-15.opb
# Benchmark53/normalized-autocorr_bern30-23.opb
# Benchmark53/normalized-autocorr_bern30-30.opb
# Benchmark53/normalized-autocorr_bern30-04.opb
# Benchmark53/normalized-autocorr_bern35-04.opb
# Benchmark53/normalized-autocorr_bern35-09.opb
# Benchmark53/normalized-autocorr_bern35-18.opb
# Benchmark53/normalized-autocorr_bern35-26.opb
# Benchmark53/normalized-autocorr_bern40-05.opb
# Benchmark53/normalized-autocorr_bern40-10.opb
# Benchmark53/normalized-autocorr_bern40-20.opb
# Benchmark53/normalized-autocorr_bern40-30.opb
# Benchmark53/normalized-autocorr_bern45-11.opb
# Benchmark53/normalized-autocorr_bern45-05.opb
# Benchmark53/normalized-autocorr_bern50-06.opb
# Benchmark53/normalized-autocorr_bern50-13.opb
# Benchmark53/normalized-autocorr_bern55-06.opb
# Benchmark53/normalized-autocorr_bern55-14.opb
# Benchmark53/normalized-autocorr_bern60-08.opb
# Benchmark53/normalized-autocorr_bern60-15.opb
# Benchmark54/normalized-crossdock_15x7.opb
# Benchmark55/normalized-edgecross10-090.opb
# Benchmark55/normalized-edgecross10-070.opb
# Benchmark55/normalized-edgecross10-050.opb
# Benchmark55/normalized-edgecross10-040.opb
# Benchmark55/normalized-edgecross10-030.opb
# Benchmark55/normalized-edgecross10-010.opb
# Benchmark55/normalized-edgecross10-020.opb
# Benchmark55/normalized-edgecross14-019.opb
# Benchmark55/normalized-edgecross14-176.opb
# Benchmark55/normalized-edgecross14-137.opb
# Benchmark55/normalized-edgecross14-117.opb
# Benchmark55/normalized-edgecross14-098.opb
# Benchmark55/normalized-edgecross14-058.opb
# Benchmark55/normalized-edgecross20-080.opb
# Benchmark55/normalized-edgecross20-040.opb
# Benchmark55/normalized-edgecross22-096.opb
# Benchmark55/normalized-edgecross22-048.opb
# Benchmark55/normalized-edgecross24-115.opb
# Benchmark55/normalized-edgecross24-057.opb
# Benchmark56/normalized-faclay20h.opb
# Benchmark56/normalized-faclay25.opb
# Benchmark56/normalized-faclay30h.opb
# Benchmark56/normalized-faclay30.opb
# Benchmark56/normalized-faclay33.opb
# Benchmark56/normalized-faclay35.opb
# Benchmark57/normalized-graphpart_2pm-0044-0044.opb
# Benchmark57/normalized-graphpart_2pm-0055-0055.opb
# Benchmark57/normalized-graphpart_2pm-0066-0066.opb
# Benchmark57/normalized-graphpart_2pm-0077-0777.opb
# Benchmark57/normalized-graphpart_2pm-0088-0888.opb
# Benchmark57/normalized-graphpart_2pm-0099-0999.opb
# Benchmark58/normalized-graphpart_3pm-0234-0234.opb
# Benchmark58/normalized-graphpart_3pm-0333-0333.opb
# Benchmark58/normalized-graphpart_3pm-0244-0244.opb
# Benchmark58/normalized-graphpart_3pm-0334-0334.opb
# Benchmark58/normalized-graphpart_3pm-0344-0344.opb
# Benchmark58/normalized-graphpart_3pm-0444-0444.opb
# Benchmark59/normalized-graphpart_clique-20.opb
# Benchmark59/normalized-graphpart_clique-30.opb
# Benchmark59/normalized-graphpart_clique-40.opb
# Benchmark59/normalized-graphpart_clique-50.opb
# Benchmark59/normalized-graphpart_clique-60.opb
# Benchmark59/normalized-graphpart_clique-70.opb
# Benchmark60/normalized-hmittelman.opb
# Benchmark61/normalized-sporttournament06.opb
# Benchmark61/normalized-sporttournament08.opb
# Benchmark61/normalized-sporttournament10.opb
# Benchmark61/normalized-sporttournament12.opb
# Benchmark61/normalized-sporttournament16.opb
# Benchmark61/normalized-sporttournament18.opb
# Benchmark61/normalized-sporttournament20.opb
# Benchmark61/normalized-sporttournament22.opb
# Benchmark61/normalized-sporttournament24.opb
# Benchmark61/normalized-sporttournament26.opb
# Benchmark61/normalized-sporttournament28.opb
# Benchmark61/normalized-sporttournament30.opb
# Benchmark61/normalized-sporttournament32.opb
# Benchmark61/normalized-sporttournament34.opb
# Benchmark61/normalized-sporttournament36.opb
# Benchmark61/normalized-sporttournament38.opb
# Benchmark61/normalized-sporttournament40.opb
# Benchmark61/normalized-sporttournament42.opb
# Benchmark61/normalized-sporttournament44.opb
# Benchmark61/normalized-sporttournament46.opb
# Benchmark61/normalized-sporttournament48.opb
# Benchmark61/normalized-sporttournament50.opb
# Benchmark62/normalized-ped2.G.recomb5-0.01-5.opb
# Benchmark62/normalized-ped2.G.recomb10-0.01-5.opb
# Benchmark62/normalized-ped2.G.recomb5-0.01-1.opb
# Benchmark62/normalized-ped2.G.recomb10-0.01-2.opb
# Benchmark62/normalized-ped2.G.recomb1-0.01-2.opb
# Benchmark62/normalized-ped2.G.recomb10-0.01-4.opb
# Benchmark62/normalized-ped2.G.recomb5-0.01-2.opb
# Benchmark62/normalized-ped2.G.recomb5-0.10-7.opb
# Benchmark62/normalized-ped2.G.recomb5-0.10-10.opb
# Benchmark62/normalized-ped2.G.recomb5-0.10-9.opb
# Benchmark62/normalized-ped2.G.recomb10-0.10-10.opb
# Benchmark62/normalized-ped2.G.recomb5-0.10-8.opb
# Benchmark62/normalized-ped2.G.recomb10-0.10-7.opb
# Benchmark62/normalized-ped2.G.recomb1-0.10-8.opb
# Benchmark62/normalized-ped2.G.recomb1-0.20-13.opb
# Benchmark62/normalized-ped2.G.recomb10-0.20-11.opb
# Benchmark62/normalized-ped2.G.recomb10-0.20-14.opb
# Benchmark62/normalized-ped2.G.recomb10-0.20-13.opb
# Benchmark62/normalized-ped2.G.recomb1-0.20-15.opb
# Benchmark63/normalized-ped3.E.recomb10-0.20-11.opb
# Benchmark63/normalized-ped3.E.recomb10-0.20-14.opb
# Benchmark64/normalized-ped3.F.recomb10-0.01-1.opb
# Benchmark64/normalized-ped3.F.recomb10-0.10-9.opb
# Benchmark64/normalized-ped3.F.recomb10-0.10-10.opb
# Benchmark64/normalized-ped3.F.recomb10-0.10-7.opb
# Benchmark64/normalized-ped3.F.recomb10-0.20-12.opb
# Benchmark65/normalized-ped3.G.recomb10-0.01-2.opb
# Benchmark65/normalized-ped3.G.recomb10-0.10-10.opb
# Benchmark65/normalized-ped3.G.recomb10-0.20-12.opb
# Benchmark65/normalized-ped3.G.recomb10-0.20-13.opb
# Benchmark66/normalized-BA_RDC4.dot_fibo_0null50mast_rapportOE1.0_TMAX300_K67_cod3.opb
# Benchmark66/normalized-BA_RDC4.dot_fibo_0null0mast_rapportOE1.0_TMAX300_K67_cod1.opb
# Benchmark66/normalized-BA_RDC4.dot_fibo_0null0mast_rapportOE1.0_TMAX180_K67_cod3.opb
# Benchmark66/normalized-BA_RDC4.dot_fibo_0null0mast_rapportOE1.0_TMAX120_K67_cod3.opb
# Benchmark66/normalized-BA_RDC4.dot_fibo_0null20mast_rapportOE2.0_TMAX120_K67_cod2.opb
# Benchmark67/normalized-BA_RDC4.dot_fibo_10null50mast_rapportOE1.0_TMAX120_K67_cod3.opb
# Benchmark67/normalized-BA_RDC4.dot_fibo_10null10mast_rapportOE1.0_TMAX300_K67_cod3.opb
# Benchmark68/normalized-BA_RDC4.dot_fibo_20null10mast_rapportOE1.0_TMAX120_K67_cod1.opb
# Benchmark68/normalized-BA_RDC4.dot_fibo_20null0mast_rapportOE2.0_TMAX15_K67_cod1.opb
# Benchmark68/normalized-BA_RDC4.dot_fibo_20null50mast_rapportOE2.0_TMAX60_K67_cod2.opb
# Benchmark69/normalized-BA_RDC4.dot_fibo_50null20mast_rapportOE2.0_TMAX60_K67_cod1.opb
# Benchmark69/normalized-BA_RDC4.dot_fibo_50null10mast_rapportOE2.0_TMAX60_K67_cod1.opb
# Benchmark69/normalized-BA_RDC4.dot_fibo_50null10mast_rapportOE2.0_TMAX300_K67_cod3.opb
# Benchmark69/normalized-BA_RDC4.dot_fibo_50null10mast_rapportOE1.0_TMAX15_K67_cod3.opb
# Benchmark69/normalized-BA_RDC4.dot_fibo_50null20mast_rapportOE1.0_TMAX15_K67_cod2.opb
# Benchmark70/normalized-BA_RDC4.dot_luby_0null50mast_rapportOE1.0_TMAX180_K67_cod1.opb
# Benchmark71/normalized-BA_RDC4.dot_luby_10null50mast_rapportOE1.0_TMAX120_K67_cod1.opb
# Benchmark71/normalized-BA_RDC4.dot_luby_10null20mast_rapportOE2.0_TMAX300_K67_cod3.opb
# Benchmark72/normalized-BA_RDC4.dot_luby_20null50mast_rapportOE1.0_TMAX15_K67_cod1.opb
# Benchmark73/normalized-BA_RDC4.dot_luby_50null20mast_rapportOE2.0_TMAX120_K67_cod1.opb
# Benchmark73/normalized-BA_RDC4.dot_luby_50null20mast_rapportOE1.0_TMAX180_K67_cod3.opb
# Benchmark74/normalized-BA_RDC4.dot_unif_0null50mast_rapportOE2.0_TMAX15_K67_cod1.opb
# Benchmark75/normalized-BA_RDC4.dot_unif_10null50mast_rapportOE2.0_TMAX120_K67_cod3.opb
# Benchmark76/normalized-BA_RDC4.dot_unif_20null50mast_rapportOE1.0_TMAX15_K67_cod3.opb
# Benchmark76/normalized-BA_RDC4.dot_unif_20null20mast_rapportOE1.0_TMAX120_K67_cod1.opb
# Benchmark76/normalized-BA_RDC4.dot_unif_20null10mast_rapportOE2.0_TMAX60_K67_cod3.opb
# Benchmark76/normalized-BA_RDC4.dot_unif_20null10mast_rapportOE2.0_TMAX60_K67_cod1.opb
# Benchmark76/normalized-BA_RDC4.dot_unif_20null10mast_rapportOE1.0_TMAX60_K67_cod1.opb
# Benchmark76/normalized-BA_RDC4.dot_unif_20null0mast_rapportOE1.0_TMAX180_K67_cod1.opb
# Benchmark77/normalized-BA_RDC4.dot_unif_50null0mast_rapportOE1.0_TMAX300_K67_cod1.opb
# Benchmark78/normalized-NG.dot_fibo_0null10mast_rapportOE1.0_TMAX180_K192_cod1.opb
# Benchmark78/normalized-NG.dot_fibo_0null50mast_rapportOE2.0_TMAX300_K192_cod2.opb
# Benchmark78/normalized-NG.dot_fibo_0null0mast_rapportOE2.0_TMAX15_K192_cod2.opb
# Benchmark79/normalized-NG.dot_fibo_10null0mast_rapportOE1.0_TMAX180_K192_cod1.opb
# Benchmark79/normalized-NG.dot_fibo_10null10mast_rapportOE2.0_TMAX15_K192_cod1.opb
# Benchmark79/normalized-NG.dot_fibo_10null10mast_rapportOE1.0_TMAX300_K192_cod1.opb
# Benchmark79/normalized-NG.dot_fibo_10null10mast_rapportOE1.0_TMAX15_K192_cod1.opb
# Benchmark80/normalized-NG.dot_fibo_20null50mast_rapportOE1.0_TMAX60_K192_cod1.opb
# Benchmark80/normalized-NG.dot_fibo_20null20mast_rapportOE2.0_TMAX120_K192_cod1.opb
# Benchmark80/normalized-NG.dot_fibo_20null50mast_rapportOE1.0_TMAX300_K192_cod2.opb
# Benchmark81/normalized-NG.dot_fibo_50null10mast_rapportOE2.0_TMAX180_K192_cod1.opb
# Benchmark81/normalized-NG.dot_fibo_50null20mast_rapportOE2.0_TMAX15_K192_cod2.opb
# Benchmark81/normalized-NG.dot_fibo_50null10mast_rapportOE2.0_TMAX15_K192_cod2.opb
# Benchmark82/normalized-NG.dot_luby_0null10mast_rapportOE1.0_TMAX300_K192_cod1.opb
# Benchmark83/normalized-NG.dot_luby_10null50mast_rapportOE2.0_TMAX60_K192_cod1.opb
# Benchmark83/normalized-NG.dot_luby_10null10mast_rapportOE2.0_TMAX60_K192_cod1.opb
# Benchmark83/normalized-NG.dot_luby_10null10mast_rapportOE2.0_TMAX15_K192_cod1.opb
# Benchmark83/normalized-NG.dot_luby_10null10mast_rapportOE1.0_TMAX60_K192_cod1.opb
# Benchmark84/normalized-NG.dot_luby_20null20mast_rapportOE2.0_TMAX300_K192_cod1.opb
# Benchmark84/normalized-NG.dot_luby_20null20mast_rapportOE2.0_TMAX120_K192_cod1.opb
# Benchmark84/normalized-NG.dot_luby_20null20mast_rapportOE1.0_TMAX300_K192_cod1.opb
# Benchmark85/normalized-NG.dot_luby_50null50mast_rapportOE2.0_TMAX300_K192_cod1.opb
# Benchmark85/normalized-NG.dot_luby_50null20mast_rapportOE1.0_TMAX180_K192_cod1.opb
# Benchmark86/normalized-NG.dot_unif_0null50mast_rapportOE1.0_TMAX300_K192_cod1.opb
# Benchmark86/normalized-NG.dot_unif_0null20mast_rapportOE2.0_TMAX120_K192_cod2.opb
# Benchmark87/normalized-NG.dot_unif_10null0mast_rapportOE2.0_TMAX60_K192_cod1.opb
# Benchmark87/normalized-NG.dot_unif_10null0mast_rapportOE2.0_TMAX300_K192_cod1.opb
# Benchmark88/normalized-NG.dot_unif_20null20mast_rapportOE2.0_TMAX180_K192_cod1.opb
# Benchmark88/normalized-NG.dot_unif_20null20mast_rapportOE2.0_TMAX120_K192_cod1.opb
# Benchmark89/normalized-NG.dot_unif_50null50mast_rapportOE1.0_TMAX15_K192_cod1.opb
# Benchmark90/normalized-minisat50_4_16_9.opb
# Benchmark90/normalized-minisat50_4_16_8.opb
# Benchmark90/normalized-minisat50_4_16_5.opb
# Benchmark90/normalized-minisat50_4_16_2.opb
# Benchmark90/normalized-minisat50_4_16_1.opb
# Benchmark90/normalized-minisat50_4_16_0.opb
# Benchmark90/normalized-minisat50_4_16_6.opb
# Benchmark91/normalized-minisat70_4_22_9.opb
# Benchmark91/normalized-minisat70_4_22_8.opb
# Benchmark91/normalized-minisat70_4_22_7.opb
# Benchmark91/normalized-minisat70_4_22_6.opb
# Benchmark91/normalized-minisat70_4_22_5.opb
# Benchmark91/normalized-minisat70_4_22_4.opb
# Benchmark91/normalized-minisat70_4_22_3.opb
# Benchmark91/normalized-minisat70_4_22_2.opb
# Benchmark91/normalized-minisat70_4_22_0.opb
# Benchmark92/normalized-minisat85_4_27_0.opb
# Benchmark92/normalized-minisat85_4_27_9.opb
# Benchmark92/normalized-minisat85_4_27_8.opb
# Benchmark92/normalized-minisat85_4_27_7.opb
# Benchmark92/normalized-minisat85_4_27_5.opb
# Benchmark92/normalized-minisat85_4_27_4.opb
# Benchmark92/normalized-minisat85_4_27_1.opb
# Benchmark93/normalized-minisat100_4_32_9.opb
# Benchmark93/normalized-minisat100_4_32_7.opb
# Benchmark93/normalized-minisat100_4_32_6.opb
# Benchmark93/normalized-minisat100_4_32_4.opb
# Benchmark93/normalized-minisat100_4_32_3.opb
# Benchmark93/normalized-minisat100_4_32_2.opb
# Benchmark93/normalized-minisat100_4_32_8.opb
# Benchmark94/normalized-minisat15_5_3_9_ic.opb
# Benchmark94/normalized-minisat15_5_3_8_ic.opb
# Benchmark94/normalized-minisat15_5_3_7_ic.opb
# Benchmark94/normalized-minisat15_5_3_6_ic.opb
# Benchmark94/normalized-minisat15_5_3_5_ic.opb
# Benchmark94/normalized-minisat15_5_3_4_ic.opb
# Benchmark94/normalized-minisat15_5_3_3_ic.opb
# Benchmark94/normalized-minisat15_5_3_2_ic.opb
# Benchmark94/normalized-minisat15_5_3_1_ic.opb
# Benchmark94/normalized-minisat15_5_3_0_ic.opb
# Benchmark95/normalized-minisat25_6_3_9_ic.opb
# Benchmark95/normalized-minisat25_6_3_8_ic.opb
# Benchmark95/normalized-minisat25_6_3_7_ic.opb
# Benchmark95/normalized-minisat25_6_3_6_ic.opb
# Benchmark95/normalized-minisat25_6_3_5_ic.opb
# Benchmark95/normalized-minisat25_6_3_4_ic.opb
# Benchmark95/normalized-minisat25_6_3_3_ic.opb
# Benchmark95/normalized-minisat25_6_3_2_ic.opb
# Benchmark95/normalized-minisat25_6_3_1_ic.opb
# Benchmark95/normalized-minisat25_6_3_0_ic.opb
# Benchmark96/normalized-minisat50_6_9_9_ic.opb
# Benchmark96/normalized-minisat50_6_9_8_ic.opb
# Benchmark96/normalized-minisat50_6_9_7_ic.opb
# Benchmark96/normalized-minisat50_6_9_6_ic.opb
# Benchmark96/normalized-minisat50_6_9_5_ic.opb
# Benchmark96/normalized-minisat50_6_9_4_ic.opb
# Benchmark96/normalized-minisat50_6_9_3_ic.opb
# Benchmark96/normalized-minisat50_6_9_2_ic.opb
# Benchmark96/normalized-minisat50_6_9_1_ic.opb
# Benchmark96/normalized-minisat50_6_9_0_ic.opb
# Benchmark97/normalized-minisat100_16_6_5_ic.opb
# Benchmark97/normalized-minisat100_16_6_2_ic.opb
# Benchmark97/normalized-minisat100_16_6_4_ic.opb
# Benchmark97/normalized-minisat100_16_6_9_ic.opb
# Benchmark97/normalized-minisat100_16_6_3_ic.opb
# Benchmark97/normalized-minisat100_16_6_6_ic.opb
# Benchmark97/normalized-minisat100_16_6_7_ic.opb
# Benchmark97/normalized-minisat100_16_6_8_ic.opb
# Benchmark97/normalized-minisat100_16_6_1_ic.opb
# Benchmark97/normalized-minisat100_16_6_0_ic.opb
# Benchmark97/normalized-minisat100_16_6_6_mh.opb
# Benchmark97/normalized-minisat100_16_6_0_mh.opb
# Benchmark97/normalized-minisat100_16_6_1_mh.opb
# Benchmark97/normalized-minisat100_16_6_3_mh.opb
# Benchmark97/normalized-minisat100_16_6_7_mh.opb
# Benchmark97/normalized-minisat100_16_6_8_mh.opb
# Benchmark97/normalized-minisat100_16_6_4_mh.opb
# Benchmark97/normalized-minisat100_16_6_9_mh.opb
# Benchmark97/normalized-minisat100_16_6_2_mh.opb
# Benchmark97/normalized-minisat100_16_6_5_mh.opb
# Benchmark98/normalized-minisat15_4_4_9_mh_ic.opb
# Benchmark98/normalized-minisat15_4_4_8_mh_ic.opb
# Benchmark98/normalized-minisat15_4_4_6_mh_ic.opb
# Benchmark98/normalized-minisat15_4_4_5_mh_ic.opb
# Benchmark98/normalized-minisat15_4_4_3_mh_ic.opb
# Benchmark98/normalized-minisat15_4_4_1_mh_ic.opb
# Benchmark98/normalized-minisat15_4_4_0_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_8_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_6_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_5_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_4_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_3_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_2_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_1_mh_ic.opb
# Benchmark99/normalized-minisat25_4_7_0_mh_ic.opb
# Benchmark100/normalized-minisat35_4_11_9_mh_ic.opb
# Benchmark100/normalized-minisat35_4_11_8_mh_ic.opb
# Benchmark100/normalized-minisat35_4_11_7_mh_ic.opb
# Benchmark100/normalized-minisat35_4_11_6_mh_ic.opb
# Benchmark100/normalized-minisat35_4_11_4_mh_ic.opb
# Benchmark100/normalized-minisat35_4_11_0_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_9_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_8_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_7_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_6_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_5_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_4_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_3_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_1_mh_ic.opb
# Benchmark101/normalized-minisat50_4_16_0_mh_ic.opb
# Benchmark102/normalized-minisat15_5_3_9_mh.opb
# Benchmark102/normalized-minisat15_5_3_8_mh.opb
# Benchmark102/normalized-minisat15_5_3_7_mh.opb
# Benchmark102/normalized-minisat15_5_3_6_mh.opb
# Benchmark102/normalized-minisat15_5_3_5_mh.opb
# Benchmark102/normalized-minisat15_5_3_4_mh.opb
# Benchmark102/normalized-minisat15_5_3_3_mh.opb
# Benchmark102/normalized-minisat15_5_3_2_mh.opb
# Benchmark102/normalized-minisat15_5_3_1_mh.opb
# Benchmark102/normalized-minisat15_5_3_0_mh.opb
# Benchmark103/normalized-minisat25_6_4_9_mh.opb
# Benchmark103/normalized-minisat25_6_4_8_mh.opb
# Benchmark103/normalized-minisat25_6_4_7_mh.opb
# Benchmark103/normalized-minisat25_6_4_6_mh.opb
# Benchmark103/normalized-minisat25_6_4_5_mh.opb
# Benchmark103/normalized-minisat25_6_4_4_mh.opb
# Benchmark103/normalized-minisat25_6_4_3_mh.opb
# Benchmark103/normalized-minisat25_6_4_2_mh.opb
# Benchmark103/normalized-minisat25_6_4_1_mh.opb
# Benchmark103/normalized-minisat25_6_4_0_mh.opb
# Benchmark104/normalized-minisat50_6_9_9_mh.opb
# Benchmark104/normalized-minisat50_6_9_8_mh.opb
# Benchmark104/normalized-minisat50_6_9_7_mh.opb
# Benchmark104/normalized-minisat50_6_9_6_mh.opb
# Benchmark104/normalized-minisat50_6_9_5_mh.opb
# Benchmark104/normalized-minisat50_6_9_4_mh.opb
# Benchmark104/normalized-minisat50_6_9_3_mh.opb
# Benchmark104/normalized-minisat50_6_9_2_mh.opb
# Benchmark104/normalized-minisat50_6_9_1_mh.opb
# Benchmark104/normalized-minisat50_6_9_0_mh.opb
# Benchmark105/normalized-ped2.B.recomb1-0.01-4.opb
# Benchmark105/normalized-ped2.B.recomb1-0.01-5.opb
# Benchmark105/normalized-ped2.B.recomb1-0.01-3.opb
# Benchmark105/normalized-ped2.B.recomb1-0.01-1.opb
# Benchmark105/normalized-ped2.B.recomb1-0.01-2.opb
# Benchmark105/normalized-ped2.B.recomb1-0.10-10.opb
# Benchmark105/normalized-ped2.B.recomb1-0.10-9.opb
# Benchmark105/normalized-ped2.B.recomb1-0.10-8.opb
# Benchmark105/normalized-ped2.B.recomb1-0.10-6.opb
# Benchmark105/normalized-ped2.B.recomb1-0.10-7.opb
# ...
# Benchmark363/normalized-m50_100_10_15.r.opb
# Benchmark363/normalized-dk512x.r.opb
# Benchmark363/normalized-m50_100_50_50.r.opb
# Benchmark363/normalized-m50_100_70_70.r.opb
# Benchmark363/normalized-m100_50_40_40.r.opb
# Benchmark363/normalized-m100_50_10_10.r.opb
# Benchmark363/normalized-m100_50_30_30.r.opb
# Benchmark363/normalized-m50_100_30_30.r.opb
# Benchmark363/normalized-m50_100_90_90.r.opb
# Benchmark363/normalized-maincont.r.opb
# Benchmark363/normalized-m100_100_10_15.r.opb
# Benchmark363/normalized-m100_100_10_30.r.opb
# Benchmark363/normalized-m100_100_30_30.r.opb
# Benchmark363/normalized-m100_100_50_50.r.opb
# Benchmark363/normalized-m100_100_70_70.r.opb
# Benchmark363/normalized-m100_100_90_90.r.opb
# Benchmark363/normalized-m100_100_10_10.r.opb
# Benchmark363/normalized-ex4inp.r.opb
# Benchmark363/normalized-m100_300_10_10.r.opb
# Benchmark363/normalized-m100_300_10_14.r.opb
# Benchmark363/normalized-m100_300_10_15.r.opb
# Benchmark363/normalized-m100_300_10_20.r.opb
# Benchmark363/normalized-ricks.r.opb
# Benchmark363/normalized-fout.r.opb
# Benchmark363/normalized-m200_500_10_10.r.opb
# Benchmark363/normalized-rd73.b.opb
# Benchmark363/normalized-C880.a.opb
# Benchmark363/normalized-max512.r.opb
# Benchmark363/normalized-mlp4.r.opb
# Benchmark363/normalized-exps.r.opb
# Benchmark363/normalized-m4.r.opb
# Benchmark363/normalized-addm4.r.opb
# Benchmark363/normalized-lin.rom.r.opb
# Benchmark363/normalized-max1024.r.opb
# Benchmark363/normalized-test1.r.opb
# Benchmark363/normalized-C880.b.opb
# Benchmark363/normalized-ex5.r.opb
# Benchmark363/normalized-apex7.b.opb
# Benchmark363/normalized-alu2.b.opb
# Benchmark363/normalized-prom2.r.opb
# Benchmark363/normalized-rd84.b.opb
# Benchmark363/normalized-bench1.r.opb
# Benchmark363/normalized-C499.a.opb
# Benchmark363/normalized-saucier.r.opb
# Benchmark363/normalized-duke2.b.opb
# Benchmark363/normalized-bw.b.opb
# Benchmark363/normalized-apex6.b.opb
# Benchmark363/normalized-des.a.opb
# Benchmark363/normalized-C499.b.opb
# Benchmark363/normalized-pdc.r.opb
# Benchmark363/normalized-ex1010.pi.opb
# Benchmark365/normalized-market-split_5_40_4.opb
# Benchmark365/normalized-market-split_5_40_2.opb
# Benchmark365/normalized-market-split_5_40_3.opb
# Benchmark365/normalized-market-split_5_40_1.opb
# Benchmark366/normalized-market-split_6_50_1.opb
# Benchmark366/normalized-market-split_6_50_2.opb
# Benchmark366/normalized-market-split_6_50_3.opb
# Benchmark366/normalized-market-split_6_50_4.opb
# Benchmark367/normalized-market-split_7_60_1.opb
# Benchmark367/normalized-market-split_7_60_2.opb
# Benchmark367/normalized-market-split_7_60_3.opb
# Benchmark368/normalized-market-split_8_70_1.opb
# Benchmark368/normalized-market-split_8_70_2.opb
# Benchmark368/normalized-market-split_8_70_3.opb
# Benchmark368/normalized-market-split_8_70_4.opb
# Benchmark369/normalized-opt-market-split_4_30_1.opb
# Benchmark369/normalized-opt-market-split_4_30_2.opb
# Benchmark369/normalized-opt-market-split_4_30_3.opb
# Benchmark369/normalized-opt-market-split_4_30_4.opb
# Benchmark370/normalized-opt-market-split_5_40_2.opb
# Benchmark370/normalized-opt-market-split_5_40_3.opb
# Benchmark370/normalized-opt-market-split_5_40_4.opb
# Benchmark370/normalized-opt-market-split_5_40_1.opb
# Benchmark371/normalized-opt-market-split_6_50_3.opb
# Benchmark371/normalized-opt-market-split_6_50_4.opb
# Benchmark371/normalized-opt-market-split_6_50_1.opb
# Benchmark371/normalized-opt-market-split_6_50_2.opb
# Benchmark372/normalized-opt-market-split_7_60_4.opb
# Benchmark372/normalized-opt-market-split_7_60_3.opb
# Benchmark372/normalized-opt-market-split_7_60_1.opb
# Benchmark372/normalized-opt-market-split_7_60_2.opb
# Benchmark373/normalized-opt-market-split_8_70_3.opb
# Benchmark373/normalized-opt-market-split_8_70_4.opb
# Benchmark373/normalized-opt-market-split_8_70_1.opb
# Benchmark373/normalized-opt-market-split_8_70_2.opb
# Benchmark374/normalized-factor-size=9-P=167-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=307-Q=317.opb
# Benchmark374/normalized-factor-size=9-P=97-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=97-Q=457.opb
# Benchmark374/normalized-factor-size=9-P=97-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=307-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=89-Q=431.opb
# Benchmark374/normalized-factor-size=9-P=89-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=307-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=307-Q=367.opb
# Benchmark374/normalized-factor-size=9-P=89-Q=263.opb
# Benchmark374/normalized-factor-size=9-P=89-Q=211.opb
# Benchmark374/normalized-factor-size=9-P=83-Q=89.opb
# Benchmark374/normalized-factor-size=9-P=307-Q=431.opb
# Benchmark374/normalized-factor-size=9-P=83-Q=367.opb
# Benchmark374/normalized-factor-size=9-P=83-Q=271.opb
# Benchmark374/normalized-factor-size=9-P=307-Q=449.opb
# Benchmark374/normalized-factor-size=9-P=31-Q=439.opb
# Benchmark374/normalized-factor-size=9-P=79-Q=257.opb
# Benchmark374/normalized-factor-size=9-P=79-Q=173.opb
# Benchmark374/normalized-factor-size=9-P=79-Q=137.opb
# Benchmark374/normalized-factor-size=9-P=313-Q=503.opb
# Benchmark374/normalized-factor-size=9-P=317-Q=389.opb
# Benchmark374/normalized-factor-size=9-P=331-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=331-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=331-Q=359.opb
# Benchmark374/normalized-factor-size=9-P=7-Q=223.opb
# Benchmark374/normalized-factor-size=9-P=7-Q=179.opb
# Benchmark374/normalized-factor-size=9-P=331-Q=379.opb
# Benchmark374/normalized-factor-size=9-P=331-Q=389.opb
# Benchmark374/normalized-factor-size=9-P=61-Q=419.opb
# Benchmark374/normalized-factor-size=9-P=331-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=347-Q=379.opb
# Benchmark374/normalized-factor-size=9-P=347-Q=419.opb
# Benchmark374/normalized-factor-size=9-P=59-Q=419.opb
# Benchmark374/normalized-factor-size=9-P=347-Q=421.opb
# Benchmark374/normalized-factor-size=9-P=347-Q=431.opb
# Benchmark374/normalized-factor-size=9-P=347-Q=439.opb
# Benchmark374/normalized-factor-size=9-P=347-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=353-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=359-Q=379.opb
# Benchmark374/normalized-factor-size=9-P=367-Q=389.opb
# Benchmark374/normalized-factor-size=9-P=5-Q=317.opb
# Benchmark374/normalized-factor-size=9-P=37-Q=107.opb
# Benchmark374/normalized-factor-size=9-P=37-Q=443.opb
# Benchmark374/normalized-factor-size=9-P=379-Q=397.opb
# Benchmark374/normalized-factor-size=9-P=47-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=379-Q=431.opb
# Benchmark374/normalized-factor-size=9-P=383-Q=509.opb
# Benchmark374/normalized-factor-size=9-P=389-Q=433.opb
# Benchmark374/normalized-factor-size=9-P=443-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=397-Q=449.opb
# Benchmark374/normalized-factor-size=9-P=409-Q=499.opb
# Benchmark374/normalized-factor-size=9-P=409-Q=509.opb
# Benchmark374/normalized-factor-size=9-P=41-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=421-Q=449.opb
# Benchmark374/normalized-factor-size=9-P=421-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=43-Q=227.opb
# Benchmark374/normalized-factor-size=9-P=431-Q=503.opb
# Benchmark374/normalized-factor-size=9-P=439-Q=509.opb
# Benchmark374/normalized-factor-size=9-P=449-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=47-Q=197.opb
# Benchmark374/normalized-factor-size=9-P=47-Q=421.opb
# Benchmark374/normalized-factor-size=9-P=47-Q=71.opb
# Benchmark374/normalized-factor-size=9-P=487-Q=499.opb
# Benchmark374/normalized-factor-size=9-P=487-Q=503.opb
# Benchmark374/normalized-factor-size=9-P=53-Q=127.opb
# Benchmark374/normalized-factor-size=9-P=53-Q=151.opb
# Benchmark374/normalized-factor-size=9-P=53-Q=191.opb
# Benchmark374/normalized-factor-size=9-P=53-Q=97.opb
# Benchmark374/normalized-factor-size=9-P=59-Q=131.opb
# Benchmark374/normalized-factor-size=9-P=59-Q=307.opb
# Benchmark374/normalized-factor-size=9-P=59-Q=337.opb
# Benchmark374/normalized-factor-size=9-P=59-Q=431.opb
# Benchmark374/normalized-factor-size=9-P=61-Q=163.opb
# Benchmark374/normalized-factor-size=9-P=61-Q=307.opb
# Benchmark374/normalized-factor-size=9-P=67-Q=191.opb
# Benchmark374/normalized-factor-size=9-P=67-Q=223.opb
# Benchmark374/normalized-factor-size=9-P=101-Q=223.opb
# Benchmark374/normalized-factor-size=9-P=101-Q=379.opb
# Benchmark374/normalized-factor-size=9-P=7-Q=31.opb
# Benchmark374/normalized-factor-size=9-P=71-Q=409.opb
# Benchmark374/normalized-factor-size=9-P=101-Q=409.opb
# Benchmark374/normalized-factor-size=9-P=71-Q=461.opb
# Benchmark374/normalized-factor-size=9-P=71-Q=491.opb
# Benchmark374/normalized-factor-size=9-P=101-Q=457.opb
# Benchmark374/normalized-factor-size=9-P=73-Q=449.opb
# Benchmark374/normalized-factor-size=9-P=107-Q=373.opb
# Benchmark374/normalized-factor-size=9-P=107-Q=503.opb
# Benchmark374/normalized-factor-size=9-P=79-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=307-Q=307.opb
# Benchmark374/normalized-factor-size=9-P=83-Q=197.opb
# Benchmark374/normalized-factor-size=9-P=109-Q=373.opb
# Benchmark374/normalized-factor-size=9-P=109-Q=419.opb
# Benchmark374/normalized-factor-size=9-P=29-Q=409.opb
# Benchmark374/normalized-factor-size=9-P=83-Q=449.opb
# Benchmark374/normalized-factor-size=9-P=11-Q=283.opb
# Benchmark374/normalized-factor-size=9-P=11-Q=53.opb
# Benchmark374/normalized-factor-size=9-P=283-Q=293.opb
# Benchmark374/normalized-factor-size=9-P=89-Q=293.opb
# Benchmark374/normalized-factor-size=9-P=89-Q=317.opb
# Benchmark374/normalized-factor-size=9-P=113-Q=233.opb
# Benchmark374/normalized-factor-size=9-P=113-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=89-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=113-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=137.opb
# Benchmark374/normalized-factor-size=9-P=257-Q=503.opb
# Benchmark374/normalized-factor-size=9-P=97-Q=509.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=149.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=211.opb
# Benchmark374/normalized-factor-size=9-P=251-Q=379.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=359.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=389.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=239-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=491.opb
# Benchmark374/normalized-factor-size=9-P=127-Q=499.opb
# Benchmark374/normalized-factor-size=9-P=13-Q=179.opb
# Benchmark374/normalized-factor-size=9-P=131-Q=137.opb
# Benchmark374/normalized-factor-size=9-P=131-Q=157.opb
# Benchmark374/normalized-factor-size=9-P=131-Q=163.opb
# Benchmark374/normalized-factor-size=9-P=131-Q=277.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=499.opb
# Benchmark374/normalized-factor-size=9-P=139-Q=191.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=163.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=167.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=379.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=251.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=271.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=293.opb
# Benchmark374/normalized-factor-size=9-P=211-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=397.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=409.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=149-Q=509.opb
# Benchmark374/normalized-factor-size=9-P=151-Q=167.opb
# Benchmark374/normalized-factor-size=9-P=157-Q=163.opb
# Benchmark374/normalized-factor-size=9-P=157-Q=181.opb
# Benchmark374/normalized-factor-size=9-P=173-Q=211.opb
# Benchmark374/normalized-factor-size=9-P=157-Q=373.opb
# Benchmark374/normalized-factor-size=9-P=167-Q=173.opb
# Benchmark374/normalized-factor-size=9-P=167-Q=179.opb
# Benchmark374/normalized-factor-size=9-P=17-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=17-Q=457.opb
# Benchmark374/normalized-factor-size=9-P=17-Q=487.opb
# Benchmark374/normalized-factor-size=9-P=173-Q=173.opb
# Benchmark374/normalized-factor-size=9-P=173-Q=191.opb
# Benchmark374/normalized-factor-size=9-P=179-Q=509.opb
# Benchmark374/normalized-factor-size=9-P=191-Q=251.opb
# Benchmark374/normalized-factor-size=9-P=191-Q=389.opb
# Benchmark374/normalized-factor-size=9-P=191-Q=449.opb
# Benchmark374/normalized-factor-size=9-P=191-Q=509.opb
# Benchmark374/normalized-factor-size=9-P=197-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=211-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=263.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=307.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=383.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=421.opb
# Benchmark374/normalized-factor-size=9-P=223-Q=431.opb
# Benchmark374/normalized-factor-size=9-P=227-Q=383.opb
# Benchmark374/normalized-factor-size=9-P=229-Q=239.opb
# Benchmark374/normalized-factor-size=9-P=229-Q=307.opb
# Benchmark374/normalized-factor-size=9-P=23-Q=293.opb
# Benchmark374/normalized-factor-size=9-P=23-Q=379.opb
# Benchmark374/normalized-factor-size=9-P=233-Q=347.opb
# Benchmark374/normalized-factor-size=9-P=239-Q=373.opb
# Benchmark374/normalized-factor-size=9-P=251-Q=277.opb
# Benchmark374/normalized-factor-size=9-P=251-Q=307.opb
# Benchmark374/normalized-factor-size=9-P=251-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=251-Q=419.opb
# Benchmark374/normalized-factor-size=9-P=257-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=257-Q=449.opb
# Benchmark374/normalized-factor-size=9-P=263-Q=307.opb
# Benchmark374/normalized-factor-size=9-P=263-Q=367.opb
# Benchmark374/normalized-factor-size=9-P=269-Q=359.opb
# Benchmark374/normalized-factor-size=9-P=269-Q=431.opb
# Benchmark374/normalized-factor-size=9-P=269-Q=433.opb
# Benchmark374/normalized-factor-size=9-P=281-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=281-Q=499.opb
# Benchmark374/normalized-factor-size=9-P=29-Q=163.opb
# Benchmark374/normalized-factor-size=9-P=29-Q=277.opb
# Benchmark374/normalized-factor-size=9-P=29-Q=331.opb
# Benchmark374/normalized-factor-size=9-P=29-Q=479.opb
# Benchmark374/normalized-factor-size=9-P=29-Q=71.opb
# Benchmark374/normalized-factor-size=9-P=293-Q=307.opb
# Benchmark375/normalized-frb30-15-5.opb
# Benchmark375/normalized-frb30-15-3.opb
# Benchmark375/normalized-frb30-15-1.opb
# Benchmark375/normalized-frb30-15-4.opb
# Benchmark375/normalized-frb30-15-2.opb
# Benchmark376/normalized-frb35-17-4.opb
# Benchmark376/normalized-frb35-17-2.opb
# Benchmark376/normalized-frb35-17-1.opb
# Benchmark376/normalized-frb35-17-3.opb
# Benchmark376/normalized-frb35-17-5.opb
# Benchmark377/normalized-frb40-19-3.opb
# Benchmark377/normalized-frb40-19-2.opb
# Benchmark377/normalized-frb40-19-1.opb
# Benchmark377/normalized-frb40-19-4.opb
# Benchmark377/normalized-frb40-19-5.opb
# Benchmark378/normalized-frb45-21-3.opb
# Benchmark378/normalized-frb45-21-4.opb
# Benchmark378/normalized-frb45-21-5.opb
# Benchmark378/normalized-frb45-21-2.opb
# Benchmark378/normalized-frb45-21-1.opb
# Benchmark379/normalized-frb50-23-5.opb
# Benchmark379/normalized-frb50-23-1.opb
# Benchmark379/normalized-frb50-23-4.opb
# Benchmark379/normalized-frb50-23-2.opb
# Benchmark379/normalized-frb50-23-3.opb
# Benchmark380/normalized-frb53-24-3.opb
# Benchmark380/normalized-frb53-24-5.opb
# Benchmark380/normalized-frb53-24-1.opb
# Benchmark380/normalized-frb53-24-2.opb
# Benchmark380/normalized-frb53-24-4.opb
# Benchmark381/normalized-frb56-25-3.opb
# Benchmark381/normalized-frb56-25-2.opb
# Benchmark381/normalized-frb56-25-5.opb
# Benchmark381/normalized-frb56-25-1.opb
# Benchmark381/normalized-frb56-25-4.opb
# Benchmark382/normalized-frb59-26-5.opb
# Benchmark382/normalized-frb59-26-3.opb
# Benchmark382/normalized-frb59-26-2.opb
# Benchmark382/normalized-frb59-26-1.opb
# Benchmark382/normalized-frb59-26-4.opb
# Benchmark383/normalized-ss97-6.opb
# Benchmark383/normalized-ws97-5.opb
# Benchmark383/normalized-ss97-4.opb
# Benchmark383/normalized-ss97-2.opb
# Benchmark384/normalized-10_10_4.5_0.5_100.opb
# Benchmark384/normalized-10_10_4.5_0.95_98.opb
# Benchmark384/normalized-10_10_4.5_0.95_100.opb
# Benchmark384/normalized-10_20_4.5_0.5_100.opb
# Benchmark384/normalized-10_20_4.5_0.95_98.opb
# Benchmark384/normalized-10_20_4.5_0.95_100.opb
# Benchmark385/normalized-30_30_4.5_0.5_100.opb
# Benchmark385/normalized-30_30_4.5_0.95_98.opb
# Benchmark385/normalized-30_30_4.5_0.95_100.opb
# Benchmark385/normalized-30_70_4.5_0.5_100.opb
# Benchmark385/normalized-30_70_4.5_0.95_98.opb
# Benchmark385/normalized-30_70_4.5_0.95_100.opb

# %%
#Crear dataframe
# dataframe with no names, so that it doesn't convert everything to str 
data=np.array([num_rest,num_var,linear,r_unary,r_binary,r_ternary,r_cuaternary,t_unary,t_binary,t_ternary,t_cuaternary,t_fo,t_pos_r,t_pos_fo,timestep,solvers])
df = pd.DataFrame(data.T, columns=columns)

#print(df.head())

# %%
x=df[["# contraints","# variables","linearity","% 1 term constr","% 2 terms constr","% 3 terms constr","% 4+ terms constr","% degree 1 terms","% degree 2 terms","% degree 3 terms","% degree 4+ terms","% terms in obj func","% positive in constr","% positive in obj func","timestep"]]
y=df[['solver']]

#agrupar diferentes timestpes de cada instancia en un mismo set
random.seed(9) #same seed to generate same random numbers as other models
train_indx=[]
inst_train=[]
test_indx=[]
for i in range(0,3128): # v4
    r = random.randint(0,2)
    if(r==2):
        for j in range(0,500):
            test_indx.append(500*i+j)
    else:
        inst_train.append(i)
        for j in range(0,500):
            train_indx.append(500*i+j)

x_train=x.iloc[train_indx]
x_test=x.iloc[test_indx]
y_train=y.iloc[train_indx]
y_test=y.iloc[test_indx]
y_train_og=y.iloc[train_indx]

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1027000, 15)
# (537000, 15)
# (1027000, 1)
# (537000, 1)

# %%
#Data augmentation para training set de instancias con clases distintas a gurobi (5)

indx_dis=[] #indexes of instances with disadvantaged labels 

#identificar instancias que tengan clase distinta a gurobi
for i in inst_train:
    has_dis=False
    for j in range(500):
        ind=500*i+j
        if(solvers[ind]!=5):
            has_dis=True
            break
    if(has_dis):
        for j in range(500):
            indx_dis.append(500*i+j)

print(len(indx_dis))
print(len(train_indx), end="\n\n")            

#agregar las instancias al final de x_train e y_train
x_train_dis=x.iloc[indx_dis]
y_train_dis=y.iloc[indx_dis]

x_train=x_train.append(x_train_dis)
y_train=y_train.append(y_train_dis)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# 674500
# 1027000
#
# (1701500, 15)
# (537000, 15)
# (1701500, 1)
# (537000, 1)

# %%
knn_model = KNeighborsClassifier(n_neighbors=21)
knn_model.fit(np.nan_to_num(x_train.astype(np.float32)), y_train.values.ravel())
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=21, p=2,
#                      weights='uniform')

# %%
y_pred = knn_model.predict(np.nan_to_num(x_test.astype(np.float32)))

# %%
print("Accuracy",metrics.accuracy_score(y_test.values.ravel(), y_pred))
pred = knn_model.predict_proba(np.nan_to_num(x_test.astype(np.float32)))
print("Loss",metrics.log_loss(y_test.values.ravel(), pred))
# Out:
# Accuracy 0.640780260707635
# Loss 9.031106962651362

# %%
#Save
l=int(len(y_test)/500)
y_test_np=y_test.to_numpy().reshape(l,500)
f = open(main_path+"models/v4/knn_nonlinear-v4/results/y_test.txt", "w")
np.savetxt(f,y_test_np.reshape(y_test_np.shape[0], -1),fmt="%s")
f.close()

l=int(len(y_pred)/500)
y_pred_np=y_pred.reshape(l,500)
f = open(main_path+"models/v4/knn_nonlinear-v4/results/y_preds.txt", "w")
np.savetxt(f,y_pred_np.reshape(y_pred_np.shape[0],-1),fmt='%s')
f.close()

#print(y_train_np.shape)
#print(y_pred_np)

# %%
l=int(len(y_train)/500)
y_train_np=y_train.to_numpy().reshape(l,500)
f = open(main_path+"models/v4/knn_nonlinear-v4/results/y_train.txt", "w")
np.savetxt(f,y_train_np.reshape(y_train_np.shape[0], -1),fmt="%s")
f.close()

l=int(len(y_train_og)/500)
y_train_og_np=y_train_og.to_numpy().reshape(l,500)
f = open(main_path+"models/v4/knn_nonlinear-v4/results/y_train_og.txt", "w")
np.savetxt(f,y_train_og_np.reshape(y_train_og_np.shape[0], -1),fmt="%s")
f.close()

# %% [markdown]
# # Prediction Time

# %%
#Calcular tiempos de predicción por cada par instancia-tiempo de test
#(Correr esto se demora 1 hora aprox)

l=int(len(y_pred)/500)
t_preds=np.empty(l*500)
i=0

#prediccion
for idx in test_indx:
    #crear dataframe de solo esa instancia-timestep
    x_i = x.iloc[[idx]]
    
    #hacer predicción y medir tiempo
    start=time.time()
    y_i = knn_model.predict(np.nan_to_num(x_i.astype(np.float32)))
    tiempo=time.time()-start
    t_preds[i]=tiempo
    
    i=i+1

# %%
#Guardar tiempos de prediccion

print(t_preds)
f = open(main_path+"models/results-v4/pred_times/t_pred_knn_nonlinear-v4.txt", "w")
np.savetxt(f, t_preds, delimiter=" ", fmt="%s")
f.close()
# Out:
# [0.00251842 0.00168681 0.00162506 ... 0.00084257 0.0008359  0.00084329]
